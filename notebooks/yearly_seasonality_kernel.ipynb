# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.templates.default = "simple_white"
pio.renderers.default = 'iframe'
from datetime import datetime, timedelta

import sys
sys.path.append('..')
from src import util

def is_leapday(date):
    return (date.month==2) & (date.day==29)
def get_increment(date):
    yesterday = date - timedelta(days=1)
    increment = 0.5 if (is_leapday(date) or is_leapday(yesterday)) else 1
    return increment
def calc_date_distance(target: datetime, anchor:datetime):
    date_range = pd.date_range(anchor, target, inclusive='right')
    # modify increment change from 1 to 0.5 before and after leap day
    increments = [get_increment(d) for d in date_range]
    return sum(increments)
def calc_adjusted_date_dist(dates: pd.Series, name='DATE_CODE'):
    """for ease of interpretation, we always use the last day of a given year as anchor 
    """
    start_date = datetime(dates.min().year, 1, 1)
    end_date = datetime(dates.max().year, 12, 31)
    dates_data = pd.DataFrame(pd.date_range(start_date, end_date, name='DATE'))
    dates_data[name]=np.cumsum([get_increment(d) for d in dates_data.DATE])
    return dates_data

# %%
data = pd.read_csv('../model_data/quality_nj2.csv')
data['DATE'] = pd.to_datetime(data.DATE)
data.head()
# Out:
#    PLT_ID         TRAIT       DATE  QUALITY  ENTRY_CODE  ENTRY_NAME  \
# 0     241  Turf Quality 2018-04-18        4          37  NAI-14-132
# 1     241  Turf Quality 2018-05-10        4          37  NAI-14-132
# 2     241  Turf Quality 2018-06-07        5          37  NAI-14-132
# 3     241  Turf Quality 2018-07-17        5          37  NAI-14-132
# 4     241  Turf Quality 2018-08-15        6          37  NAI-14-132
#
#                   COMP RATER  ROW  COL  PLOC_CODE  YEAR MONTH    RATING_EVENT  \
# 0  Columbia River Seed   RMD   17    1        239  2018   Apr  RMD-2018-04-18
# 1  Columbia River Seed   RON   17    1        239  2018   May  RON-2018-05-10
# 2  Columbia River Seed   RON   17    1        239  2018   Jun  RON-2018-06-07
# 3  Columbia River Seed   RON   17    1        239  2018   Jul  RON-2018-07-17
# 4  Columbia River Seed   RMD   17    1        239  2018   Aug  RMD-2018-08-15
#
#    RATING_EVENT_CODE  MONTH_CODE  YEAR_CODE      TEST_LOC
# 0                  8           1          1  Adelphia, NJ
# 1                 13           6          1  Adelphia, NJ
# 2                 14           4          1  Adelphia, NJ
# 3                 15           3          1  Adelphia, NJ
# 4                  9           2          1  Adelphia, NJ

# %%
entry_sample = np.random.choice(data.ENTRY_NAME.unique(), 5)
entry_sample
# Out:
# array(['A13-1', 'DLFPS-340/3364', 'NAI-15-80', 'A16-2', 'Babe'],
#       dtype=object)

# %%
px.scatter(data[data.ENTRY_NAME.isin(entry_sample)].sort_values(by='DATE'), 
                x='DATE', y='QUALITY', color='ENTRY_NAME', trendline='lowess', trendline_options=dict(frac=0.1))
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_274.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# date distance were calculated using the last day of the year before the year on which the trial was established.

# %%
dates_data = calc_adjusted_date_dist(data.DATE)
dates_data.head()
# Out:
#         DATE  DATE_CODE
# 0 2018-01-01        1.0
# 1 2018-01-02        2.0
# 2 2018-01-03        3.0
# 3 2018-01-04        4.0
# 4 2018-01-05        5.0

# %%
data = pd.merge(data, dates_data, on='DATE')
data.head()
# Out:
#    PLT_ID         TRAIT       DATE  QUALITY  ENTRY_CODE      ENTRY_NAME  \
# 0     241  Turf Quality 2018-04-18        4          37      NAI-14-132
# 1     240  Turf Quality 2018-04-18        5          25    BAR PP 7236V
# 2     211  Turf Quality 2018-04-18        6          59  DLFPS-340/3455
# 3     210  Turf Quality 2018-04-18        3          75           A15-6
# 4     181  Turf Quality 2018-04-18        3          31       NAI-15-80
#
#                        COMP RATER  ROW  COL  PLOC_CODE  YEAR MONTH  \
# 0       Columbia River Seed   RMD   17    1        239  2018   Apr
# 1        Barenbrug Research   RMD   16    1        238  2018   Apr
# 2          DLF Pickseed USA   RMD   15    1        209  2018   Apr
# 3       Peak Plant Genetics   RMD   14    1        208  2018   Apr
# 4  SiteOne Landscape Supply   RMD   13    1        179  2018   Apr
#
#      RATING_EVENT  RATING_EVENT_CODE  MONTH_CODE  YEAR_CODE      TEST_LOC  \
# 0  RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 1  RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 2  RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 3  RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 4  RMD-2018-04-18                  8           1          1  Adelphia, NJ
#
#    DATE_CODE
# 0      108.0
# 1      108.0
# 2      108.0
# 3      108.0
# 4      108.0

# %%
px.violin(x=data.DATE, y=data.QUALITY, color=data.RATER)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_258.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# The prior knowledge for the annual turfgrass growth is summarized using product of periodic and squared exponential covariance function (with period 365):
# $$K_d(\cdot) = \sigma_d^2 exp({-\frac{2\sin^2 (\pi(d-d')/365)}{l_{d}^2}})
# $$
# $d = d(t)$ is a modified time with time before and after leap day incremented by 0.5 day so that in d the length of the year is always 365, wheter in common year or leap year.
#
# ## TODO: add local variablity by adding
# $$K_d(\cdot) = \sigma_d^2 exp({-\frac{2\sin^2 (\pi(d-d')/365)}{l_{d,1}^2}})exp({-\frac{|d-d'|^2}{l_{d,2}^2}})$$

# %%
data = data.assign(RATER_CODE=pd.Categorical(data.RATER).codes + 1)

# %%
data
# Out:
#       PLT_ID         TRAIT       DATE  QUALITY  ENTRY_CODE         ENTRY_NAME  \
# 0        241  Turf Quality 2018-04-18        4          37         NAI-14-132
# 1        240  Turf Quality 2018-04-18        5          25       BAR PP 7236V
# 2        211  Turf Quality 2018-04-18        6          59     DLFPS-340/3455
# 3        210  Turf Quality 2018-04-18        3          75              A15-6
# 4        181  Turf Quality 2018-04-18        3          31          NAI-15-80
# ...      ...           ...        ...      ...         ...                ...
# 9607      75  Turf Quality 2021-11-18        6          75              A15-6
# 9608      46  Turf Quality 2021-11-18        5          46  Bombay (GO-22B23)
# 9609      45  Turf Quality 2021-11-18        5          45               Skye
# 9610      16  Turf Quality 2021-11-18        7          16             J-1138
# 9611      15  Turf Quality 2021-11-18        5          15     After Midnight
#
#                           COMP RATER  ROW  COL  PLOC_CODE  YEAR MONTH  \
# 0          Columbia River Seed   RMD   17    1        239  2018   Apr
# 1           Barenbrug Research   RMD   16    1        238  2018   Apr
# 2             DLF Pickseed USA   RMD   15    1        209  2018   Apr
# 3          Peak Plant Genetics   RMD   14    1        208  2018   Apr
# 4     SiteOne Landscape Supply   RMD   13    1        179  2018   Apr
# ...                        ...   ...  ...  ...        ...   ...   ...
# 9607       Peak Plant Genetics   WAM    5   15         75  2021   Nov
# 9608          Grassland Oregon   WAM    4   15         46  2021   Nov
# 9609                  Standard   WAM    3   15         45  2021   Nov
# 9610   Jacklin Seed by Simplot   WAM    2   15         16  2021   Nov
# 9611   Jacklin Seed by Simplot   WAM    1   15         15  2021   Nov
#
#         RATING_EVENT  RATING_EVENT_CODE  MONTH_CODE  YEAR_CODE      TEST_LOC  \
# 0     RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 1     RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 2     RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 3     RMD-2018-04-18                  8           1          1  Adelphia, NJ
# 4     RMD-2018-04-18                  8           1          1  Adelphia, NJ
# ...              ...                ...         ...        ...           ...
# 9607  WAM-2021-11-18                 36           7          4  Adelphia, NJ
# 9608  WAM-2021-11-18                 36           7          4  Adelphia, NJ
# 9609  WAM-2021-11-18                 36           7          4  Adelphia, NJ
# 9610  WAM-2021-11-18                 36           7          4  Adelphia, NJ
# 9611  WAM-2021-11-18                 36           7          4  Adelphia, NJ
#
#       DATE_CODE  RATER_CODE
# 0         108.0           4
# 1         108.0           4
# 2         108.0           4
# 3         108.0           4
# 4         108.0           4
# ...         ...         ...
# 9607     1417.0           7
# 9608     1417.0           7
# 9609     1417.0           7
# 9610     1417.0           7
# 9611     1417.0           7
#
# [9612 rows x 20 columns]

# %%
pred_dates = pd.date_range(dates_data.DATE.min(), dates_data.DATE.max(), freq='W-MON')
pred_data = dates_data[dates_data.DATE.isin(pred_dates)]
pred_data
# Out:
#            DATE  DATE_CODE
# 0    2018-01-01        1.0
# 7    2018-01-08        8.0
# 14   2018-01-15       15.0
# 21   2018-01-22       22.0
# 28   2018-01-29       29.0
# ...         ...        ...
# 1428 2021-11-29     1428.0
# 1435 2021-12-06     1435.0
# 1442 2021-12-13     1442.0
# 1449 2021-12-20     1449.0
# 1456 2021-12-27     1456.0
#
# [209 rows x 2 columns]

# %%
model_data = util.get_model_data(data)
model_data['ii'] = np.asarray(data.RATER_CODE)
model_data['I'] = int(max(model_data['ii']))
model_data['tt'] = np.asarray(data.DATE_CODE)
model_data['T'] = int(max(np.asarray(model_data['tt'])))
model_data['period'] = 365
model_data
# Out:
# {'y': array([3, 4, 5, ..., 4, 6, 4]),
#  'ii': array([4, 4, 4, ..., 7, 7, 7], dtype=int8),
#  'jj': array([37, 25, 59, ..., 45, 16, 15]),
#  'pp': array([239, 238, 209, ...,  45,  16,  15]),
#  'N': 9612,
#  'M': 8,
#  'I': 7,
#  'J': 89,
#  'P': 267,
#  'tt': array([ 108.,  108.,  108., ..., 1417., 1417., 1417.]),
#  'T': 1417,
#  'period': 365}

# %%
from cmdstanpy import CmdStanModel
